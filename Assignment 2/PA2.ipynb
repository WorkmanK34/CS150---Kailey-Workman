# %% [markdown]
# # Assingment 2
# Kailey Workman - Spring 2026

# %% [markdown]
# ## Task 1

# %%
myname = 'Kailey Workman'
myage = '22'
myheight = '177'
myfavcolour = 'Yellow'
print('My name is ' + myname + ', I am ' + myage + ' years old. I am ' + myheight + 'cm tall. My favourite colour is ' + myfavcolour +'.')
# Out:
# My name is Kailey Workman, I am 22 years old. I am 177cm tall. My favourite colour is Yellow.

# %% [markdown]
# ## Task 2

# %%
miles_distance = 24
kilometer_distance = miles_distance * 1.60934
print('The distance is ' +str(miles_distance) + ' miles, which is the equivalent of ' + str(kilometer_distance) + ' kilometers.')
# Out:
# The distance is 24 miles, which is the equivalent of 38.62416 kilometers.

# %% [markdown]
# ## Task 3

# %%
run1 = 13
run2 = 7
total_time = run1 + run2
print('The total time spent running was '+str(total_time)+ ' minutes.')
improvement = run1 - run2
print('There was an improvement of '+str(improvement)+ ' minutes.')
run2_twice = run2 * 2
print('If you ran run 2 again twice at the same pace it would take you '+str(run2_twice)+ ' minutes.')
average = (run1+run2)/2
print('The average time of your runs was '+str(average)+ ' minutes.')
# Out:
# The total time spent running was 20 minutes.
# There was an improvement of 6 minutes.
# If you ran run 2 again twice at the same pace it would take you 14 minutes.
# The average time of your runs was 10.0 minutes.

# %% [markdown]
# ## Task 4

# %%
quote = 'You miss 100% of the shots you do not take'
print(len(quote))
print(quote.upper())
print(quote.lower())
print(quote.strip())
print(quote.split( ))
# Out:
# 42
# YOU MISS 100% OF THE SHOTS YOU DO NOT TAKE
# you miss 100% of the shots you do not take
# You miss 100% of the shots you do not take
# ['You', 'miss', '100%', 'of', 'the', 'shots', 'you', 'do', 'not', 'take']

# %% [markdown]
# ## Task 5

# %%
a = int(input('What is your first side length?'))
b = int(input('What is you rsecond side length?'))
c = ((a**2)+(b**2))**(1/2)
print('The hypotenuse of your triangle is ' + str(round(c,2)) + ' units.')
# Out:
# What is your first side length?7
# What is you rsecond side length?4
# The hypotenuse of your triangle is 8.06 units.
