# %% [markdown]
# # Kailey Workman - Markdown Practice

# %% [markdown]
# ### I am a senior studying Biochemistry and Molecular Biology on the Pre Medical track. I began learning to code in my 9th grade math class and I really enjoyed it. So far I have learned Java, Java Script, and a bit of HTML. I have taken 2 comp sci classes and 2 computer engineering classes in highschool. I am excited to learn Python and add to my coding knowledge.

# %% [markdown]
# The course activities for this class include:
# * 5 Programming Assignments
# * 4 Quizzes
# * 2 Mid-Term Exams
# * 2 Projects
# * Attendence and Participation Activities

# %% [markdown]
# The modules we will be adressing are:
# 1. Module 1: Variables, Simple Data, Types, and GitHub Discussion
# 2. Module 2: Lists and Tuples Part 1
# 3. Module 3: If Statments
# 4. Module 4: Loops
# 5. Module 5: Lists and Tuples Part 2
# 6. Module 6: Dictionaries
# 7. Module 7: Sets, Function, Libraries
# 8. Module 8: Class Datatypes and Exceptions
# 9. Module 9: NumPy Arrays
# 10. Module 10: Pandas and File Excerpt

# %% [markdown]
# The primary language we will learn in this class is **Python**

# %% [markdown]
# The software we are using to create/edi our .ipynb files is *Jupyter in Anacando*

# %% [markdown]
# Today I went to the gym and it was very fun. It was my first time lifting in the SuRF by myself without my team which was a little weird. I did alot of excersises including `back squats` and `reverse lunges`.

# %% [markdown]
# [My Git Account] (https://github.com/WorkmanK34)

# %% [markdown]
# ![School Logo](Logo.PNG)

# %% [markdown]
# In this Markdown practice I learned how to utilize typography within a Python code. This includes writing in bold, italics, and title case, as well as highlighting text, inserting links and images, and using headers.
